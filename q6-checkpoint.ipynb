# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
df = pd.read_csv("us-marriages-divorces-1867-2014.csv", usecols=['Year','Marriages_per_1000','Divorces_per_1000'])
df
# Out:
#      Year  Marriages_per_1000  Divorces_per_1000
# 0    1867                 9.7                0.3
# 1    1868                 9.1                0.3
# 2    1869                 9.0                0.3
# 3    1870                 8.8                0.3
# 4    1871                 8.8                0.3
# ..    ...                 ...                ...
# 140  2007                 7.3                2.8
# 141  2008                 7.1                2.8
# 142  2009                 6.8                2.7
# 143  2010                 6.8                2.8
# 144  2011                 6.8                2.8
#
# [145 rows x 3 columns]

# %%
df.plot(x='Year')
plt.ylabel('Per 1000 people')
plt.title('Marriages and divorces per capita')
plt.show()
