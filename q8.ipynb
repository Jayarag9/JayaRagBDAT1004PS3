# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
df = pd.read_csv("actor_kill_counts.csv").sort_values("Count", ascending=True)
df
# Out:
#                    Actor  Count
# 9          Wesley Snipes    193
# 3             Clive Owen    194
# 5                 Jet Li    201
# 6           Nicolas Cage    204
# 2         Clint Eastwood    207
# 8    Tomisaburo Wakayama    226
# 4         Dolph Lundgren    239
# 7     Sylvester Stallone    267
# 1           Chow Yun-Fat    295
# 0  Arnold Schwarzenegger    369

# %%
df.plot.barh(x='Actor')
plt.ylabel('Kill Count')
plt.title('Actor Kill Count')
plt.show()
